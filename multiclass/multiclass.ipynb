# %%
import pandas as pd

# %%
data=pd.read_csv('/home/ykalathiya/pycaret_assignment/multiclass/Student_performance_data _.csv')
drop_columns=['StudentID']
data=data.drop(columns=drop_columns)
data.head()
# Out:
#    Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0   17       1          0                  2        19.833723         7
# 1   18       0          0                  1        15.408756         0
# 2   15       0          2                  3         4.210570        26
# 3   17       1          0                  3        10.028829        14
# 4   17       1          0                  2         4.672495        17
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 0         1                2                0       0      1             0
# 1         0                1                0       0      0             0
# 2         0                2                0       0      0             0
# 3         0                3                1       0      0             0
# 4         1                3                0       0      0             0
#
#         GPA  GradeClass
# 0  2.929196         2.0
# 1  3.042915         1.0
# ...

# %%
from pycaret.classification import *
s = ClassificationExperiment()

# %%
s.setup(data=data,
        target='GradeClass',
        session_id=123,
        normalize=True,
        transformation=True)
# Out:
# <style type="text/css">
# #T_f53cd_row8_col1, #T_f53cd_row12_col1, #T_f53cd_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f53cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f53cd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f53cd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f53cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f53cd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f53cd_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f53cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f53cd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f53cd_row1_col1" class="data row1 col1" >GradeClass</td>
#     </tr>
#     <tr>
# ...

# %%
best_model = s.compare_models()
# Out:
# <style type="text/css">
# #T_97e00 th {
#   text-align: left;
# }
# ...

# %%
s.evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Save the best model for future use
s.save_model(best_model, 'best_student_performance_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Age', 'Gender', 'Ethnicity',
#                                               'ParentalEducation',
#                                               'StudyTimeWeekly', 'Absences',
#                                               'Tutoring', 'ParentalSupport',
#                                               'Extracurricular', 'Sports',
#                                               'Music', 'Volunteering', 'GPA'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empt...
# ...

# %%
# Predict on the same data (or you can use new/unseen data)
predictions = s.predict_model(best_model)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_03c1e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03c1e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_03c1e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_03c1e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_03c1e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_03c1e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_03c1e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_03c1e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_03c1e_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03c1e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03c1e_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
# ...

# %%
lightgbm = s.create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_80068_row10_col0, #T_80068_row10_col1, #T_80068_row10_col2, #T_80068_row10_col3, #T_80068_row10_col4, #T_80068_row10_col5, #T_80068_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_80068">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80068_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_80068_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_80068_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_80068_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_80068_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_80068_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_80068_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
data.describe()
# Out:
#                Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000        2392.000000
# mean     16.468645     0.510870     0.877508           1.746237
# std       1.123798     0.499986     1.028476           1.000411
# min      15.000000     0.000000     0.000000           0.000000
# 25%      15.000000     0.000000     0.000000           1.000000
# 50%      16.000000     1.000000     0.000000           2.000000
# 75%      17.000000     1.000000     2.000000           2.000000
# max      18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# min           0.001057     0.000000     0.000000         0.000000
# ...

# %%
s.create_app(lightgbm,None)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
