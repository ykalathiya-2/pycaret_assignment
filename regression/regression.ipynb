# %% [markdown]
# # Car Price Regression with PyCaret
# This notebook uses PyCaret to build a regression model for predicting car prices based on various features from the `CarPrice_Assignment.csv` dataset.
#
# **Problem Statement:**
# A Chinese automobile company wants to understand the factors affecting car prices in the US market. The goal is to model car prices using available features to help management understand pricing dynamics and inform business strategy.
#
# **Dataset:**
# - `CarPrice_Assignment.csv`: Contains various features of cars and their prices.
#
# **Steps:**
# 1. Load the dataset
# 2. Set up PyCaret regression experiment
# 3. Compare models and select the best
# 4. Evaluate and save the best model
# 5. Predict car prices

# %%
# Import required libraries
import pandas as pd
import numpy as np

# %%
# Load the dataset
data = pd.read_csv('CarPrice_Assignment.csv')
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
# PyCaret Regression Setup
from pycaret.regression import RegressionExperiment
reg = RegressionExperiment()
reg.setup(data=data, target='price', session_id=123, normalize=True, transformation=True)
# Out:
# <style type="text/css">
# #T_249d8_row9_col1, #T_249d8_row15_col1, #T_249d8_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_249d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_249d8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_249d8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_249d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_249d8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_249d8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_249d8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_249d8_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_249d8_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_249d8_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_249d8_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_249d8_row3_col1" class="data row3 col1" >(205, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_249d8_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_249d8_row4_col1" class="data row4 col1" >(205, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_249d8_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_249d8_row5_col1" class="data row5 col1" >(143, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_249d8_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_249d8_row6_col1" class="data row6 col1" >(62, 51)</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_249d8_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_249d8_row7_col1" class="data row7 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_249d8_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_249d8_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_249d8_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_249d8_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_249d8_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_249d8_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_249d8_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_249d8_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_249d8_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_249d8_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_249d8_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_249d8_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_249d8_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_249d8_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_249d8_row15_col0" class="data row15 col0" >Transformation</td>
#       <td id="T_249d8_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_249d8_row16_col0" class="data row16 col0" >Transformation method</td>
#       <td id="T_249d8_row16_col1" class="data row16 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_249d8_row17_col0" class="data row17 col0" >Normalize</td>
#       <td id="T_249d8_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_249d8_row18_col0" class="data row18 col0" >Normalize method</td>
#       <td id="T_249d8_row18_col1" class="data row18 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_249d8_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_249d8_row19_col1" class="data row19 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_249d8_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_249d8_row20_col1" class="data row20 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_249d8_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_249d8_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_249d8_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_249d8_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_249d8_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_249d8_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_249d8_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_249d8_row24_col1" class="data row24 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_249d8_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_249d8_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_249d8_row25_col1" class="data row25 col1" >494f</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Compare models and select the best
best_model = reg.compare_models()
# Out:
# <style type="text/css">
# #T_1b919 th {
#   text-align: left;
# }
# #T_1b919_row0_col0, #T_1b919_row1_col0, #T_1b919_row1_col1, #T_1b919_row1_col2, #T_1b919_row1_col3, #T_1b919_row1_col4, #T_1b919_row1_col5, #T_1b919_row1_col6, #T_1b919_row2_col0, #T_1b919_row2_col1, #T_1b919_row2_col2, #T_1b919_row2_col3, #T_1b919_row2_col4, #T_1b919_row2_col5, #T_1b919_row2_col6, #T_1b919_row3_col0, #T_1b919_row3_col1, #T_1b919_row3_col2, #T_1b919_row3_col3, #T_1b919_row3_col4, #T_1b919_row3_col5, #T_1b919_row3_col6, #T_1b919_row4_col0, #T_1b919_row4_col1, #T_1b919_row4_col2, #T_1b919_row4_col3, #T_1b919_row4_col4, #T_1b919_row4_col5, #T_1b919_row4_col6, #T_1b919_row5_col0, #T_1b919_row5_col1, #T_1b919_row5_col2, #T_1b919_row5_col3, #T_1b919_row5_col4, #T_1b919_row5_col5, #T_1b919_row5_col6, #T_1b919_row6_col0, #T_1b919_row6_col1, #T_1b919_row6_col2, #T_1b919_row6_col3, #T_1b919_row6_col4, #T_1b919_row6_col5, #T_1b919_row6_col6, #T_1b919_row7_col0, #T_1b919_row7_col1, #T_1b919_row7_col2, #T_1b919_row7_col3, #T_1b919_row7_col4, #T_1b919_row7_col5, #T_1b919_row7_col6, #T_1b919_row8_col0, #T_1b919_row8_col1, #T_1b919_row8_col2, #T_1b919_row8_col3, #T_1b919_row8_col4, #T_1b919_row8_col5, #T_1b919_row8_col6, #T_1b919_row9_col0, #T_1b919_row9_col1, #T_1b919_row9_col2, #T_1b919_row9_col3, #T_1b919_row9_col4, #T_1b919_row9_col5, #T_1b919_row9_col6, #T_1b919_row10_col0, #T_1b919_row10_col1, #T_1b919_row10_col2, #T_1b919_row10_col3, #T_1b919_row10_col4, #T_1b919_row10_col5, #T_1b919_row10_col6, #T_1b919_row11_col0, #T_1b919_row11_col1, #T_1b919_row11_col2, #T_1b919_row11_col3, #T_1b919_row11_col4, #T_1b919_row11_col5, #T_1b919_row11_col6, #T_1b919_row12_col0, #T_1b919_row12_col1, #T_1b919_row12_col2, #T_1b919_row12_col3, #T_1b919_row12_col4, #T_1b919_row12_col5, #T_1b919_row12_col6, #T_1b919_row13_col0, #T_1b919_row13_col1, #T_1b919_row13_col2, #T_1b919_row13_col3, #T_1b919_row13_col4, #T_1b919_row13_col5, #T_1b919_row13_col6, #T_1b919_row14_col0, #T_1b919_row14_col1, #T_1b919_row14_col2, #T_1b919_row14_col3, #T_1b919_row14_col4, #T_1b919_row14_col5, #T_1b919_row14_col6, #T_1b919_row15_col0, #T_1b919_row15_col1, #T_1b919_row15_col2, #T_1b919_row15_col3, #T_1b919_row15_col4, #T_1b919_row15_col5, #T_1b919_row15_col6, #T_1b919_row16_col0, #T_1b919_row16_col1, #T_1b919_row16_col2, #T_1b919_row16_col3, #T_1b919_row16_col4, #T_1b919_row16_col5, #T_1b919_row16_col6, #T_1b919_row17_col0, #T_1b919_row17_col1, #T_1b919_row17_col2, #T_1b919_row17_col3, #T_1b919_row17_col4, #T_1b919_row17_col5, #T_1b919_row17_col6 {
#   text-align: left;
# }
# #T_1b919_row0_col1, #T_1b919_row0_col2, #T_1b919_row0_col3, #T_1b919_row0_col4, #T_1b919_row0_col5, #T_1b919_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1b919_row0_col7, #T_1b919_row1_col7, #T_1b919_row2_col7, #T_1b919_row3_col7, #T_1b919_row5_col7, #T_1b919_row6_col7, #T_1b919_row7_col7, #T_1b919_row8_col7, #T_1b919_row9_col7, #T_1b919_row10_col7, #T_1b919_row11_col7, #T_1b919_row12_col7, #T_1b919_row13_col7, #T_1b919_row14_col7, #T_1b919_row15_col7, #T_1b919_row16_col7, #T_1b919_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_
col7" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_1b919_level0_row5" class="row_heading level0 row5" >en</th>
#       <td id="T_1b919_row5_col0" class="data row5 col0" >Elastic Net</td>
#       <td id="T_1b919_row5_col1" class="data row5 col1" >2454.9655</td>
#       <td id="T_1b919_row5_col2" class="data row5 col2" >12157188.5585</td>
#       <td id="T_1b919_row5_col3" class="data row5 col3" >3417.0587</td>
#       <td id="T_1b919_row5_col4" class="data row5 col4" >0.7865</td>
#       <td id="T_1b919_row5_col5" class="data row5 col5" >0.2726</td>
#       <td id="T_1b919_row5_col6" class="data row5 col6" >0.1878</td>
#       <td id="T_1b919_row5_col7" class="data row5 col7" >0.0330</td>

# %%
# Evaluate the best model
reg.evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Save the best model for future use
reg.save_model(best_model, 'best_car_price_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['car_ID', 'symboling', 'wheelbase',
#                                               'carlength', 'carwidth',
#                                               'carheight', 'curbweight',
#                                               'enginesize', 'boreratio',
#                                               'stroke', 'compressionratio',
#                                               'horsepower', 'peakrpm', 'citympg',
#                                               'highwaympg'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(inc...
#                                                                use_cat_names=True))),
#                  ('rest_encoding',
#                   TransformerWrapper(include=['CarName'],
#                                      transformer=TargetEncoder(cols=['CarName'],
#                                                                handle_missing='return_nan'))),
#                  ('transformation',
#                   TransformerWrapper(transformer=PowerTransformer(standardize=False))),
#                  ('normalize', TransformerWrapper(transformer=StandardScaler())),
#                  ('trained_model', GradientBoostingRegressor(random_state=123))]),
#  'best_car_price_model.pkl')

# %%
# Predict car prices on the same data (or new/unseen data)
predictions = reg.predict_model(best_model)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_8267e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8267e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8267e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8267e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8267e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8267e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8267e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8267e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8267e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8267e_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_8267e_row0_col1" class="data row0 col1" >1098.1978</td>
#       <td id="T_8267e_row0_col2" class="data row0 col2" >2609733.6283</td>
#       <td id="T_8267e_row0_col3" class="data row0 col3" >1615.4670</td>
#       <td id="T_8267e_row0_col4" class="data row0 col4" >0.9203</td>
#       <td id="T_8267e_row0_col5" class="data row0 col5" >0.1317</td>
#       <td id="T_8267e_row0_col6" class="data row0 col6" >0.1042</td>
#     </tr>
#   </tbody>
# </table>
#      car_ID  symboling                    CarName fueltype aspiration  \
# 88       89         -1       mitsubishi mirage g4      gas        std
# 72       73          3              buick skylark      gas        std
# 114     115          0  peugeot 505s turbo diesel   diesel      turbo
# 158     159          0              toyota corona   diesel        std
# 163     164          1    toyota corolla liftback      gas        std
#
#     doornumber      carbody drivewheel enginelocation   wheelbase  ...  \
# 88        four        sedan        fwd          front   96.300003  ...
# 72         two  convertible        rwd          front   96.599998  ...
# 114       four        wagon        rwd          front  114.199997  ...
# 158       four        sedan        fwd          front   95.699997  ...
# 163        two        sedan        rwd          front   94.500000  ...
#
#      fuelsystem  boreratio  stroke  compressionratio horsepower peakrpm  \
# 88         spdi       3.17    3.46               7.5        116    5500
# 72         mpfi       3.46    3.10               8.3        155    4750
# 114         idi       3.70    3.52              21.0         95    4150
# 158         idi       3.27    3.35              22.5         56    4500
# 163        2bbl       3.19    3.03               9.0         70    4800
#
#      citympg highwaympg    price  prediction_label
# 88        23         30   9279.0       9011.780403
# 72        16         18  35056.0      32303.355150
# 114       25         25  17075.0      17259.228021
# 158       34         36   7898.0       8415.955824
# 163       29         34   8058.0       7979.098467
#
# [5 rows x 27 columns]
